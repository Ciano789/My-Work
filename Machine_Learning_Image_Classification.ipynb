# %% [markdown]
# ### Assignment 3 - Image Classification
#
# ###### Student Name: Cian O Brien
# ###### Student Number: R00101689

# %%
# Run some setup code for this notebook.
from __future__ import print_function
import random
import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import os
from random import shuffle


# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-4e1ccb75ac85> in <module>()
#       6 import matplotlib.pyplot as plt
#       7 from matplotlib.image import imread
# ----> 8 import cv2
#       9 import os
#      10 from random import shuffle
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# ###### Load and plot the first nine photos of dogs

# %%
TRAIN_DIR = 'C:/Users/obria/Desktop/Year2/ML/Assignment3/data/train/'
TEST_DIR = 'C:/Users/obria/Desktop/Year2/ML/Assignment3/data/test/'
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# define filename
	filename = folder + 'dog.' + str(i) + '.jpg'
	# load image pixels
	image = imread(filename)
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()
